# %% [markdown]
# # GG4257 - Urban Analytics: A Toolkit for Sustainable Urban Development
# ## Lab Assignment No 2: Networks, Geodemographics and Spatial Microsimulation.
#
# # General Information
# - **Student ID No:** 220002252
# - **Degree Programme:** Geography
# - **Deadline Date:** 2nd April 2025
#
# # GitHub Repository
# - **GitHub Link:** https://github.com/beapinol/UrbanAn
#
# # Declaration
#
# In submitting this assignment, I hereby confirm that I have read the University's statement on Good Academic Practice. The following work is my own. Significant academic debts and borrowings have been properly acknowledged and referenced.

# %% [markdown]
# # Table of Contents
#
# 1. [Introduction](#Introduction)
# - How to replicate the code and get the required data
#
#
# 2.  <u>Lab Five: <u>
# - <a href="lab5/LabFive.1.ipynb">Challenge One
# - <a href="lab5/LabFive.2.ipynb">Challenge Two
#
#
# 3.  <u>Lab Six: <u>
# - <a href="lab6/Lab6.ipynb"> Challenge One
#
#
# 4.  <u>Lab Seven: <u>
# - <a href="lab7/Lab7.ipynb"> Challenge One
#
#
# 5. [Final Remarks](#Final-Remarks)

# %% [markdown]
# # Introduction
# How to Replicate the Code and Instructions on how to get required data, if needed.
#
# To access the data to download to your local computer the data has been organised into a folder for each lab in this google drive: https://drive.google.com/drive/folders/1Ba4Trxz3VKxwicAtNLYZjCWU_wwooXKV?usp=drive_link, for which permission has been granted.
#
# The directories in the assignment folder have been assigned to LabFive, LabSix, LabSeven etc. and inside each folder the directories remain exactly the same as what is contained within the lab.
# As long as all instructions in markdown cells or denoted by # are followed the code should run.

# %% [markdown]
# # Final Remarks
# **Limitations**
# **Barriers**
# - storage for Lab Six Challenge two made me have to switch to a smaller city
# **Additional Comments**

# %%
#exploring outdoor crime dataset

# %%
#importing the dataset

# %%
import json

with open('data/outdoor_crime/outdoor_crime.json', 'r') as f:
    data = json.load(f)

#exploring the data type
print(type(data))
# Out:
# <class 'dict'>

# %%
#printing only the top-level keys

# %%
print(data.keys())
# Out:
# dict_keys(['fields', 'records'])

# %%
import pandas as pd
records = data["records"]
df = pd.DataFrame(records)
df.head()
# Out:
#    0   1   2        3                                      4       5   \
# 0   1   0   1  Assault  Non-domestic violence related assault  Sydney
# 1   2   1   2  Assault  Non-domestic violence related assault  Sydney
# 2   3   2   3  Assault  Non-domestic violence related assault  Sydney
# 3   4   3   5  Assault  Non-domestic violence related assault  Sydney
# 4   5   4   6  Assault  Non-domestic violence related assault  Sydney
#
#               6                     7     8          9   ...         11    12  \
# 0        REDFERN  OUTDOOR/PUBLIC PLACE  2016 -33.892390  ...  Intersect  2012
# 1         SYDNEY  OUTDOOR/PUBLIC PLACE  2000 -33.867700  ...  Intersect  2012
# 2  WOOLLOOMOOLOO  OUTDOOR/PUBLIC PLACE  2011 -33.872671  ...    Address  2013
# 3  WOOLLOOMOOLOO  OUTDOOR/PUBLIC PLACE  2011 -33.870260  ...  Intersect  2013
# 4    SURRY HILLS  OUTDOOR/PUBLIC PLACE  2010 -33.880070  ...  Intersect  2013
#
#         13       14     15    16        17 18         19        20
# ...

# %%
#checking out the column titles
df.columns
# Out:
# RangeIndex(start=0, stop=21, step=1)

# %%
#it is difficult to manipulate this type of data so we will convert it to a csv file

# %%
df = pd.read_json(data)
df.to_csv('outdoor_crime.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = pd.read_json(data)
#       2 df.to_csv('outdoor_crime.csv', index=False)
#
# File ~\MiniForge\Lib\site-packages\pandas\io\json\_json.py:791, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     788 if convert_axes is None and orient != "table":
#     789     convert_axes = True
# --> 791 json_reader = JsonReader(
#     792     path_or_buf,
#     793     orient=orient,
#     794     typ=typ,
#     795     dtype=dtype,
#     796     convert_axes=convert_axes,
#     797     convert_dates=convert_dates,
#     798     keep_default_dates=keep_default_dates,
#     799     precise_float=precise_float,
# ...
